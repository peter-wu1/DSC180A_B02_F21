# %%
# !pip install mwapi
# Out:
# Collecting mwapi
#   Downloading mwapi-0.5.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\peter\anaconda3\lib\site-packages (from mwapi) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peter\anaconda3\lib\site-packages (from requests->mwapi) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\peter\anaconda3\lib\site-packages (from requests->mwapi) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\peter\anaconda3\lib\site-packages (from requests->mwapi) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\peter\anaconda3\lib\site-packages (from requests->mwapi) (2.10)
# Installing collected packages: mwapi
# Successfully installed mwapi-0.5.1

# %%
import pandas as pd
import mwapi
import numpy as np
import json
pd.set_option("max_colwidth", 500)

# %% [markdown]
# The session object is your API connection to a Wikimedia subdomain (or any other wiki using MediaWiki with the API enabled). Change the user agent to your Wikipedia username.

# %%
session = mwapi.Session("https://en.wikipedia.org",
                        user_agent="User:P5Wu")

# %% [markdown]
# `session.get()` is the main API query function.
#
# The API is organized hierarchially by action and then property. Most data scraping / read only requests use "action:query" and "prop:XYZ" to specify the properties you want to query. The "prop:revisions" is used to retrieve information by edits to pages (e.g. all edits to the California article). The "prop:contributors" does queries by user (e.g. all edits by Staeiou). See [the_documentation](https://www.mediawiki.org/wiki/API:Properties) for more properties to query.
#
# Each prop module has a set of its own parameters, so prop:revisions has rvprop, where you specify what variables you want returned. There is also a prop-specific limit variable for the number of results per request. The max return size for most queries is 500 items per request. But with the continuation=True parameter in mwapi, it is easier to use a python generator to iterate over to get more than 500 items.
#
# The mwapi library auto-throttles, so don't worry about rate limiting.

# %%
ucsd_revs = session.get(action="query",
                        prop="revisions",
                        titles="University of California, San Diego",
                        rvprop="ids|timestamp|comment|user|userid|size|tags|roles",
                        rvlimit=500,
                        continuation=True)

# %%
type(ucsd_revs)
# Out:
# generator

# %%
requests = []
for request in ucsd_revs:
    requests.append(request)

# %%
len(requests)
# Out:
# 8

# %% [markdown]
# The raw json from a single request, with 500 revisions. It can be a bit tricky to get just the revisions into a pandas dataframe:

# %%
print(json.dumps(requests[0], indent=2))
# Out:
# {
#   "continue": {
#     "rvcontinue": "20171127212014|812439364",
#     "continue": "||"
#   },
#   "query": {
#     "pages": {
#       "31927": {
#         "pageid": 31927,
#         "ns": 0,
#         "title": "University of California, San Diego",
#         "revisions": [
#           {
#             "revid": 1050338887,
#             "parentid": 1050203530,
#             "user": "ShelfSkewed",
#             "userid": 1152308,
#             "timestamp": "2021-10-17T07:12:48Z",
#             "size": 160107,
#             "roles": [
#               "main"
#             ],
#             "comment": "Links fixes",
#             "tags": []
#           },
#           {
#             "revid": 1050203530,
#             "parentid": 1050178467,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-10-16T11:56:35Z",
#             "size": 160079,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated enrollment figures for Fall 2021",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1050178467,
#             "parentid": 1048818404,
#             "user": "97.115.51.56",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-10-16T07:42:29Z",
#             "size": 160490,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1048818404,
#             "parentid": 1047751245,
#             "user": "Sgweirdo",
#             "userid": 39921276,
#             "timestamp": "2021-10-08T04:53:33Z",
#             "size": 160500,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1047751245,
#             "parentid": 1047400554,
#             "user": "PrimeBOT",
#             "userid": 29463730,
#             "timestamp": "2021-10-02T11:26:29Z",
#             "size": 160508,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* External links */[[User:PrimeBOT/24|Task 24]]: removal of a template following [[Wikipedia:Templates_for_discussion/Log/2021_September_24|a TFD]]",
#             "tags": [
#               "AWB"
#             ]
#           },
#           {
#             "revid": 1047400554,
#             "parentid": 1047087304,
#             "user": "Citation bot",
#             "userid": 7903804,
#             "timestamp": "2021-09-30T17:23:39Z",
#             "size": 160546,
#             "roles": [
#               "main"
#             ],
#             "comment": "Add: date. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Anas1712 | [[Category:Public universities and colleges in California]] | #UCB_Category 44/71",
#             "tags": []
#           },
#           {
#             "revid": 1047087304,
#             "parentid": 1044776975,
#             "user": "128.54.85.162",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-09-28T23:12:25Z",
#             "size": 160526,
#             "roles": [
#               "main"
#             ],
#             "comment": "Removed Chi Phi as Chapter is no longer active, Removed Sigma Chi as chapter has been suspended from campus and is no longer formally recognized due to Sexual Assault allegations.",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1044776975,
#             "parentid": 1044746541,
#             "user": "MB",
#             "userid": 26021349,
#             "timestamp": "2021-09-17T01:40:15Z",
#             "size": 160554,
#             "roles": [
#               "main"
#             ],
#             "comment": "cleanup, [[WP:AWB/T|typo(s) fixed]]: Center \u2192 center, from 2009\u20132013 \u2192 from 2009 to 2013, four year \u2192 four-year",
#             "tags": [
#               "AWB"
#             ]
#           },
#           {
#             "revid": 1044746541,
#             "parentid": 1044216498,
#             "user": "MB",
#             "userid": 26021349,
#             "timestamp": "2021-09-16T21:34:39Z",
#             "size": 160563,
#             "roles": [
#               "main"
#             ],
#             "comment": "Rmv undefined, unsupported, deprecated infobox parameters",
#             "tags": []
#           },
#           {
#             "revid": 1044216498,
#             "parentid": 1044103365,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-09-14T04:44:47Z",
#             "size": 160285,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Rankings */ update",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1044103365,
#             "parentid": 1044103254,
#             "user": "Estateiii",
#             "userid": 40163877,
#             "timestamp": "2021-09-13T15:46:09Z",
#             "size": 160285,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Rankings */",
#             "tags": []
#           },
#           {
#             "revid": 1044103254,
#             "parentid": 1043229035,
#             "user": "Estateiii",
#             "userid": 40163877,
#             "timestamp": "2021-09-13T15:45:21Z",
#             "size": 160284,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Rankings */ Update Washington Monthly ranking to #12 from #9 to reflect 2021 issue (https://washingtonmonthly.com/2021college-guide/national)",
#             "tags": []
#           },
#           {
#             "revid": 1043229035,
#             "parentid": 1043054284,
#             "user": "Ucsdtriton1964",
#             "userid": 42468459,
#             "timestamp": "2021-09-09T01:22:38Z",
#             "size": 160283,
#             "roles": [
#               "main"
#             ],
#             "comment": "Edit Forbes' ranking",
#             "tags": []
#           },
#           {
#             "revid": 1043054284,
#             "parentid": 1039761243,
#             "user": "Cewbot",
#             "userid": 23646674,
#             "timestamp": "2021-09-08T03:57:55Z",
#             "size": 160283,
#             "roles": [
#               "main"
#             ],
#             "comment": "[[User:Cewbot/log/20201008/configuration|Fix broken anchor]]: [[Special:Diff/747761791|2016-11-04]] #University of California, San Diego\u21dd[[List of Nobel laureates by university affiliation#University of California, Berkeley (3rd)]]",
#             "tags": []
#           },
#           {
#             "revid": 1039761243,
#             "parentid": 1037772974,
#             "user": "Citation bot",
#             "userid": 7903804,
#             "timestamp": "2021-08-20T15:46:14Z",
#             "size": 160278,
#             "roles": [
#               "main"
#             ],
#             "comment": "Alter: url. URLs might have been anonymized. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Abductive | #UCB_webform 634/2200",
#             "tags": []
#           },
#           {
#             "revid": 1037772974,
#             "parentid": 1036660287,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-08-08T16:43:26Z",
#             "size": 160298,
#             "roles": [
#               "main"
#             ],
#             "comment": "update numbers and source",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1036660287,
#             "parentid": 1036659597,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-08-01T23:55:21Z",
#             "size": 160546,
#             "roles": [
#               "main"
#             ],
#             "comment": "Created two separate sentences for clarity.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1036659597,
#             "parentid": 1034812232,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-08-01T23:48:25Z",
#             "size": 160531,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated research and development expenditure figures and ranking, per the most recent 2019 National Science Foundation (NSF) report.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1034812232,
#             "parentid": 1034748361,
#             "user": "GreenC bot",
#             "userid": 27823944,
#             "timestamp": "2021-07-21T23:57:02Z",
#             "size": 160531,
#             "roles": [
#               "main"
#             ],
#             "comment": "Reformat 1 archive link; Move 1 url. [[User:GreenC/WaybackMedic_2.5|Wayback Medic 2.5]]",
#             "tags": []
#           },
#           {
#             "revid": 1034748361,
#             "parentid": 1034449531,
#             "user": "Goszei",
#             "userid": 36510957,
#             "timestamp": "2021-07-21T15:48:34Z",
#             "size": 160528,
#             "roles": [
#               "main"
#             ],
#             "comment": "Changing [[Wikipedia:Short description|short description]] from \"Public research university in San Diego, California\" to \"Public university in San Diego, California\" ([[Wikipedia:Shortdesc helper|Shortdesc helper]])",
#             "tags": []
#           },
#           {
#             "revid": 1034449531,
#             "parentid": 1034081071,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-07-19T23:01:26Z",
#             "size": 160537,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated application figures for Fall 2021.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1034081071,
#             "parentid": 1034081025,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-07-17T17:26:39Z",
#             "size": 160541,
#             "roles": [
#               "main"
#             ],
#             "comment": "Undid revision 1034081025 by [[Special:Contributions/Wikiman5676|Wikiman5676]] ([[User talk:Wikiman5676|talk]]) self revert",
#             "tags": [
#               "mw-undo"
#             ]
#           },
#           {
#             "revid": 1034081025,
#             "parentid": 1033858778,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-07-17T17:26:11Z",
#             "size": 160539,
#             "roles": [
#               "main"
#             ],
#             "comment": "move image",
#             "tags": [
#               "visualeditor",
#               "mw-reverted"
#             ]
#           },
#           {
#             "revid": 1033858778,
#             "parentid": 1033300164,
#             "user": "185.172.241.184",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-07-16T08:41:13Z",
#             "size": 160541,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */",
#             "tags": [
#               "mw-add-media",
#               "mw-remove-media"
#             ]
#           },
#           {
#             "revid": 1033300164,
#             "parentid": 1028881140,
#             "user": "Rodw",
#             "userid": 125972,
#             "timestamp": "2021-07-12T20:37:53Z",
#             "size": 160539,
#             "roles": [
#               "main"
#             ],
#             "comment": "Disambiguating links to [[Terry Allen]] (link changed to [[Terry Allen (artist)]]) using [[User:Qwertyytrewqqwerty/DisamAssist|DisamAssist]].",
#             "tags": []
#           },
#           {
#             "revid": 1028881140,
#             "parentid": 1028812393,
#             "user": "71.220.210.236",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-06-16T15:19:18Z",
#             "size": 160518,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Greek life */",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1028812393,
#             "parentid": 1028429308,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-06-16T05:05:05Z",
#             "size": 160500,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated staff count",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1028429308,
#             "parentid": 1028429026,
#             "user": "Stelline2000",
#             "userid": 41427077,
#             "timestamp": "2021-06-13T23:02:49Z",
#             "size": 160496,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 1028429026,
#             "parentid": 1027787454,
#             "user": "Stelline2000",
#             "userid": 41427077,
#             "timestamp": "2021-06-13T23:00:22Z",
#             "size": 160488,
#             "roles": [
#               "main"
#             ],
#             "comment": "Added internal link",
#             "tags": []
#           },
#           {
#             "revid": 1027787454,
#             "parentid": 1025562558,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-06-10T00:50:19Z",
#             "size": 160462,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Rankings */ Updated QS ranking",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1025562558,
#             "parentid": 1025562449,
#             "user": "Irabony622",
#             "userid": 36193575,
#             "timestamp": "2021-05-28T07:28:01Z",
#             "size": 160462,
#             "roles": [
#               "main"
#             ],
#             "comment": "I moved an image slightly",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1025562449,
#             "parentid": 1025561926,
#             "user": "Irabony622",
#             "userid": 36193575,
#             "timestamp": "2021-05-28T07:27:19Z",
#             "size": 160465,
#             "roles": [
#               "main"
#             ],
#             "comment": "I added an image",
#             "tags": [
#               "visualeditor",
#               "mw-add-media"
#             ]
#           },
#           {
#             "revid": 1025561926,
#             "parentid": 1025190126,
#             "user": "Irabony622",
#             "userid": 36193575,
#             "timestamp": "2021-05-28T07:23:08Z",
#             "size": 160298,
#             "roles": [
#               "main"
#             ],
#             "comment": "I added an image",
#             "tags": [
#               "visualeditor",
#               "mw-add-media"
#             ]
#           },
#           {
#             "revid": 1025190126,
#             "parentid": 1024794844,
#             "user": "USA Eagle01",
#             "userid": 40554499,
#             "timestamp": "2021-05-26T07:22:05Z",
#             "size": 160156,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Student life */",
#             "tags": []
#           },
#           {
#             "revid": 1024794844,
#             "parentid": 1024794757,
#             "user": "USA Eagle01",
#             "userid": 40554499,
#             "timestamp": "2021-05-24T03:46:35Z",
#             "size": 160130,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Traditions */",
#             "tags": [
#               "mw-manual-revert"
#             ]
#           },
#           {
#             "revid": 1024794757,
#             "parentid": 1024794598,
#             "user": "USA Eagle01",
#             "userid": 40554499,
#             "timestamp": "2021-05-24T03:45:55Z",
#             "size": 161052,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Traditions */",
#             "tags": [
#               "mw-reverted"
#             ]
#           },
#           {
#             "revid": 1024794598,
#             "parentid": 1023116930,
#             "user": "USA Eagle01",
#             "userid": 40554499,
#             "timestamp": "2021-05-24T03:44:26Z",
#             "size": 160130,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Student life */",
#             "tags": []
#           },
#           {
#             "revid": 1023116930,
#             "parentid": 1022170879,
#             "user": "Citation bot",
#             "userid": 7903804,
#             "timestamp": "2021-05-14T13:26:50Z",
#             "size": 160212,
#             "roles": [
#               "main"
#             ],
#             "comment": "Alter: title. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by AManWithNoPlan | Linked from User:AManWithNoPlan/sandbox2 | #UCB_webform_linked 135/142",
#             "tags": []
#           },
#           {
#             "revid": 1022170879,
#             "parentid": 1021333293,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-05-08T22:18:04Z",
#             "size": 160214,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ Future tense -> past tense, and added links to other UC campuses",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1021333293,
#             "parentid": 1021119836,
#             "user": "ElKevbo",
#             "userid": 217538,
#             "timestamp": "2021-05-04T04:23:39Z",
#             "size": 160084,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* top */ discussed at https://en.wikipedia.org/wiki/Wikipedia_talk:WikiProject_Higher_education/Archive_12#Listing_of_affiliations_that_should_be_removed_from_infoboxes",
#             "tags": []
#           },
#           {
#             "revid": 1021119836,
#             "parentid": 1021119676,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-05-03T00:57:53Z",
#             "size": 160148,
#             "roles": [
#               "main"
#             ],
#             "comment": "Saved link from disambiguation",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1021119676,
#             "parentid": 1020969614,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-05-03T00:56:28Z",
#             "size": 160136,
#             "roles": [
#               "main"
#             ],
#             "comment": "Linked to Triton",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020969614,
#             "parentid": 1020799617,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-05-02T04:18:45Z",
#             "size": 160126,
#             "roles": [
#               "main"
#             ],
#             "comment": "Reorganized introduction for better logical flow.",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020799617,
#             "parentid": 1020715520,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-05-01T02:50:43Z",
#             "size": 160109,
#             "roles": [
#               "main"
#             ],
#             "comment": "reorder paragraph more logically",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020715520,
#             "parentid": 1020625523,
#             "user": "Blimpherd",
#             "userid": 41716693,
#             "timestamp": "2021-04-30T17:01:39Z",
#             "size": 160109,
#             "roles": [
#               "main"
#             ],
#             "comment": "Moved summary of rankings to first paragraph because other university pages include it there.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1020625523,
#             "parentid": 1020625457,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-04-30T03:49:54Z",
#             "size": 160109,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Construction */",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020625457,
#             "parentid": 1020282892,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-04-30T03:49:11Z",
#             "size": 160116,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Construction */",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020282892,
#             "parentid": 1020276707,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-04-28T07:16:56Z",
#             "size": 160120,
#             "roles": [
#               "main"
#             ],
#             "comment": "Changing [[Wikipedia:Short description|short description]] from \"Public research university in La Jolla, California\" to \"Public research university in San Diego, California\" ([[Wikipedia:Shortdesc helper|Shortdesc helper]])",
#             "tags": []
#           },
#           {
#             "revid": 1020276707,
#             "parentid": 1020276029,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-28T06:11:25Z",
#             "size": 160119,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* External links */ add ELs. remove seemingly unrelated one",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020276029,
#             "parentid": 1020275500,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-28T06:05:19Z",
#             "size": 160112,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Housing */ delete photos, i realize these are outdated",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020275500,
#             "parentid": 1020224929,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-28T05:59:22Z",
#             "size": 160720,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Housing */ add photos",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1020224929,
#             "parentid": 1019659079,
#             "user": "Blimpherd",
#             "userid": 41716693,
#             "timestamp": "2021-04-27T22:34:59Z",
#             "size": 160115,
#             "roles": [
#               "main"
#             ],
#             "comment": "Summarized rankings.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit",
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019659079,
#             "parentid": 1019584731,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-24T17:18:45Z",
#             "size": 159582,
#             "roles": [
#               "main"
#             ],
#             "comment": "expand",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019584731,
#             "parentid": 1019570151,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-24T05:39:54Z",
#             "size": 159540,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ reword for accuracy",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019570151,
#             "parentid": 1019408092,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-24T02:43:32Z",
#             "size": 159458,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ add info",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019408092,
#             "parentid": 1019404502,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T04:51:00Z",
#             "size": 158507,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Housing */ specify",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019404502,
#             "parentid": 1019404243,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T04:12:13Z",
#             "size": 158489,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* National rankings */ this doesnt belong in a section about academic rankings",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019404243,
#             "parentid": 1019403705,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T04:09:06Z",
#             "size": 159104,
#             "roles": [
#               "main"
#             ],
#             "comment": "Rescuing 176 sources and tagging 0 as dead.) #IABot (v2.0.8",
#             "tags": [
#               "OAuth CID: 1804"
#             ]
#           },
#           {
#             "revid": 1019403705,
#             "parentid": 1019403516,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T04:03:46Z",
#             "size": 127811,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Housing */ update info",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019403516,
#             "parentid": 1019401246,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T04:01:44Z",
#             "size": 127807,
#             "roles": [
#               "main"
#             ],
#             "comment": "add info",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019401246,
#             "parentid": 1019400995,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T03:40:06Z",
#             "size": 127396,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Housing */ updated info per source",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1019400995,
#             "parentid": 1017882347,
#             "user": "Wikiman5676",
#             "userid": 28537347,
#             "timestamp": "2021-04-23T03:37:36Z",
#             "size": 127433,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Residential colleges */ add chart to better organize info. remove unsourced data",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1017882347,
#             "parentid": 1017634872,
#             "user": "2601:643:8000:9E80:1833:ECB0:5E5F:C97",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-04-15T03:31:14Z",
#             "size": 125782,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Academics and administration */",
#             "tags": []
#           },
#           {
#             "revid": 1017634872,
#             "parentid": 1017634786,
#             "user": "Unclespook",
#             "userid": 37140251,
#             "timestamp": "2021-04-13T21:13:12Z",
#             "size": 125778,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Public art */",
#             "tags": []
#           },
#           {
#             "revid": 1017634786,
#             "parentid": 1017603146,
#             "user": "Unclespook",
#             "userid": 37140251,
#             "timestamp": "2021-04-13T21:12:27Z",
#             "size": 125756,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Public art */",
#             "tags": []
#           },
#           {
#             "revid": 1017603146,
#             "parentid": 1017602984,
#             "user": "Unclespook",
#             "userid": 37140251,
#             "timestamp": "2021-04-13T17:57:00Z",
#             "size": 125595,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Public art */",
#             "tags": []
#           },
#           {
#             "revid": 1017602984,
#             "parentid": 1017285646,
#             "user": "Unclespook",
#             "userid": 37140251,
#             "timestamp": "2021-04-13T17:55:57Z",
#             "size": 125591,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Public art */",
#             "tags": []
#           },
#           {
#             "revid": 1017285646,
#             "parentid": 1017203189,
#             "user": "94.38.236.247",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-04-11T22:33:33Z",
#             "size": 125563,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* External links */ UCSD copyright and Creative Commons policy",
#             "tags": []
#           },
#           {
#             "revid": 1017203189,
#             "parentid": 1013332810,
#             "user": "Theologian81sp",
#             "userid": 41536391,
#             "timestamp": "2021-04-11T12:54:26Z",
#             "size": 125436,
#             "roles": [
#               "main"
#             ],
#             "comment": "fix footnote (empty title)",
#             "tags": []
#           },
#           {
#             "revid": 1013332810,
#             "parentid": 1012928443,
#             "user": "InternetArchiveBot",
#             "userid": 27015025,
#             "timestamp": "2021-03-21T01:13:35Z",
#             "size": 125356,
#             "roles": [
#               "main"
#             ],
#             "comment": "Rescuing 5 sources and tagging 0 as dead.) #IABot (v2.0.8) ([[User:AManWithNoPlan|AManWithNoPlan]] - 7487",
#             "tags": []
#           },
#           {
#             "revid": 1012928443,
#             "parentid": 1011507388,
#             "user": "104.167.182.210",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-03-19T02:42:42Z",
#             "size": 124493,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */",
#             "tags": []
#           },
#           {
#             "revid": 1011507388,
#             "parentid": 1010497171,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-03-11T07:11:44Z",
#             "size": 124485,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Residential colleges */ Added photo of Warren",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1010497171,
#             "parentid": 1009466142,
#             "user": "Filetime",
#             "userid": 38612296,
#             "timestamp": "2021-03-05T19:58:07Z",
#             "size": 124375,
#             "roles": [
#               "main"
#             ],
#             "comment": "I cleaned up some images.",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1009466142,
#             "parentid": 1009181255,
#             "user": "Coolcaesar",
#             "userid": 95921,
#             "timestamp": "2021-02-28T19:06:33Z",
#             "size": 124516,
#             "roles": [
#               "main"
#             ],
#             "comment": "Fixing this mess",
#             "tags": []
#           },
#           {
#             "revid": 1009181255,
#             "parentid": 1005352940,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-02-27T04:48:16Z",
#             "size": 124397,
#             "roles": [
#               "main"
#             ],
#             "comment": "Deleted bullet points for formatting consistency.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1005352940,
#             "parentid": 1005166773,
#             "user": "Coolcaesar",
#             "userid": 95921,
#             "timestamp": "2021-02-07T06:44:15Z",
#             "size": 124375,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ Fixing missing link",
#             "tags": []
#           },
#           {
#             "revid": 1005166773,
#             "parentid": 1004551741,
#             "user": "27.97.3.67",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-02-06T08:38:07Z",
#             "size": 124360,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1004551741,
#             "parentid": 1004550501,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-02-03T04:17:23Z",
#             "size": 124358,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated the date listed.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1004550501,
#             "parentid": 1004434544,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-02-03T04:05:42Z",
#             "size": 124356,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated school colors with ampersand symbol for better readability.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1004434544,
#             "parentid": 1002473706,
#             "user": "Tanisk325",
#             "userid": 41133172,
#             "timestamp": "2021-02-02T15:52:26Z",
#             "size": 124358,
#             "roles": [
#               "main"
#             ],
#             "comment": "Included San Diego website with information. #1Lib1Ref",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 1002473706,
#             "parentid": 1002207430,
#             "user": "106.76.154.232",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-01-24T16:57:42Z",
#             "size": 124229,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated fact about endowment",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 1002207430,
#             "parentid": 999663493,
#             "user": "Mean as custard",
#             "userid": 10962546,
#             "timestamp": "2021-01-23T09:49:41Z",
#             "size": 124232,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 999663493,
#             "parentid": 997788827,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2021-01-11T08:58:00Z",
#             "size": 124246,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Student life */ Seven, not six colleges.",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997788827,
#             "parentid": 997788352,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-01-02T06:45:48Z",
#             "size": 124141,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated/corrected title card description.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 997788352,
#             "parentid": 997784971,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-01-02T06:41:17Z",
#             "size": 124135,
#             "roles": [
#               "main"
#             ],
#             "comment": "Footnote was outdated.  Previously\nlinked to the Department of Family Medicine and Public Health.  Updated to the new Wertheim School of Public Health website.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 997784971,
#             "parentid": 997784279,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-01-02T06:10:49Z",
#             "size": 124114,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated acreage to match the acreage listed in the info box.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 997784279,
#             "parentid": 997751344,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2021-01-02T06:04:19Z",
#             "size": 124114,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated school colors.  Pantone 2767 has been designated UC San Diego Blue and Pantone 1245 has been designated UC San Diego Yellow.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit",
#               "self-published-blog"
#             ]
#           },
#           {
#             "revid": 997751344,
#             "parentid": 997306567,
#             "user": "SassySalt",
#             "userid": 40892664,
#             "timestamp": "2021-01-02T01:45:51Z",
#             "size": 124147,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997306567,
#             "parentid": 997306271,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-12-30T22:42:38Z",
#             "size": 124110,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Construction */ Remove extra spacing",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997306271,
#             "parentid": 997304604,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-12-30T22:41:09Z",
#             "size": 124112,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Admissions */ Link to school of medicine",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997304604,
#             "parentid": 997304142,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-12-30T22:32:21Z",
#             "size": 124108,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Research */ grammar",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997304142,
#             "parentid": 997270561,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-12-30T22:30:01Z",
#             "size": 124107,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Research */ Added various research institutes and miscellaneous readability",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 997270561,
#             "parentid": 996946521,
#             "user": "TritonsRising",
#             "userid": 23960444,
#             "timestamp": "2020-12-30T19:29:07Z",
#             "size": 122788,
#             "roles": [
#               "main"
#             ],
#             "comment": "fixed article publication date",
#             "tags": [
#               "mobile edit",
#               "mobile app edit",
#               "ios app edit"
#             ]
#           },
#           {
#             "revid": 996946521,
#             "parentid": 996521102,
#             "user": "Hypercephalic",
#             "userid": 12822909,
#             "timestamp": "2020-12-29T08:39:41Z",
#             "size": 122788,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */",
#             "tags": []
#           },
#           {
#             "revid": 996521102,
#             "parentid": 996093102,
#             "user": "Monkbot",
#             "userid": 20483999,
#             "timestamp": "2020-12-27T02:36:34Z",
#             "size": 122790,
#             "roles": [
#               "main"
#             ],
#             "comment": "[[User:Monkbot/task 18|Task 18 (cosmetic)]]: eval 202 templates: hyphenate params (146\u00d7);",
#             "tags": [
#               "AWB"
#             ]
#           },
#           {
#             "revid": 996093102,
#             "parentid": 994932789,
#             "user": "2603:8081:160A:BE2A:6410:2FE2:EF18:42CE",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2020-12-24T14:02:41Z",
#             "size": 122644,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 994932789,
#             "parentid": 991592273,
#             "user": "USA Eagle01",
#             "userid": 40554499,
#             "timestamp": "2020-12-18T08:27:38Z",
#             "size": 122631,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Rankings */",
#             "tags": []
#           },
#           {
#             "revid": 991592273,
#             "parentid": 991414303,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-11-30T21:28:13Z",
#             "size": 122631,
#             "roles": [
#               "main"
#             ],
#             "comment": "Remove outdated note",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 991414303,
#             "parentid": 989682257,
#             "user": "Monkbot",
#             "userid": 20483999,
#             "timestamp": "2020-11-29T23:08:13Z",
#             "size": 122950,
#             "roles": [
#               "main"
#             ],
#             "comment": "[[User:Monkbot/task 18|Task 18 (cosmetic)]]: eval 203 templates: del empty params (27\u00d7); hyphenate params (16\u00d7); del |ref=harv (6\u00d7); del |url-status= (4\u00d7);",
#             "tags": [
#               "AWB"
#             ]
#           },
#           {
#             "revid": 989682257,
#             "parentid": 989678838,
#             "user": "Citation bot",
#             "userid": 7903804,
#             "timestamp": "2020-11-20T12:04:57Z",
#             "size": 123312,
#             "roles": [
#               "main"
#             ],
#             "comment": "Add: s2cid. | You can [[WP:UCB|use this bot]] yourself. [[WP:DBUG|Report bugs here]]. | Suggested by Abductive | All pages linked from cached copy of User:Abductive/sandbox | via #UCB_webform_linked 205/848",
#             "tags": []
#           },
#           {
#             "revid": 989678838,
#             "parentid": 989632534,
#             "user": "76.9.69.235",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2020-11-20T11:33:27Z",
#             "size": 123281,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Student life */ split 2 paras",
#             "tags": []
#           },
#           {
#             "revid": 989632534,
#             "parentid": 989282288,
#             "user": "76.9.69.235",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2020-11-20T03:14:45Z",
#             "size": 123273,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ split overly long paras",
#             "tags": []
#           },
#           {
#             "revid": 989282288,
#             "parentid": 989142009,
#             "user": "ChromeGames",
#             "userid": 26127603,
#             "timestamp": "2020-11-18T02:26:01Z",
#             "size": 123267,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Residential colleges */Update Seventh",
#             "tags": [
#               "mobile edit",
#               "mobile web edit",
#               "advanced mobile edit"
#             ]
#           },
#           {
#             "revid": 989142009,
#             "parentid": 989012053,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-11-17T08:16:58Z",
#             "size": 123264,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Campus */ seven not six colleges",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 989012053,
#             "parentid": 988718594,
#             "user": "76.88.1.92",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2020-11-16T15:29:33Z",
#             "size": 123262,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated the enrollment numbers in the opening paragraph to match those listed in the info box.",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 988718594,
#             "parentid": 988635705,
#             "user": "Coolcaesar",
#             "userid": 95921,
#             "timestamp": "2020-11-14T21:21:10Z",
#             "size": 123276,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */ Fixing URL",
#             "tags": []
#           },
#           {
#             "revid": 988635705,
#             "parentid": 988634890,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-11-14T10:26:24Z",
#             "size": 123206,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated enrollment for Fall 2020 in infobox",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 988634890,
#             "parentid": 987292000,
#             "user": "AndyrooP",
#             "userid": 35513381,
#             "timestamp": "2020-11-14T10:17:56Z",
#             "size": 123211,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Campus */ No longer \"soon to be seven colleges\"",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 987292000,
#             "parentid": 987075928,
# ...
#             "revid": 827451211,
#             "parentid": 827298415,
#             "user": "TritonsRising",
#             "userid": 23960444,
#             "timestamp": "2018-02-24T20:19:08Z",
#             "size": 104487,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 827298415,
#             "parentid": 827259864,
#             "user": "ElKevbo",
#             "userid": 217538,
#             "timestamp": "2018-02-23T22:38:49Z",
#             "size": 104497,
#             "roles": [
#               "main"
#             ],
#             "comment": "rv undiscussed edits by editor who has already been blocked once for this exact same behavior",
#             "tags": []
#           },
#           {
#             "revid": 827259864,
#             "parentid": 827038255,
#             "user": "69.71.194.34",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2018-02-23T18:04:43Z",
#             "size": 104049,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 827038255,
#             "parentid": 827034352,
#             "user": "Amorymeltzer",
#             "userid": 141948,
#             "timestamp": "2018-02-22T12:00:24Z",
#             "size": 104497,
#             "roles": [
#               "main"
#             ],
#             "comment": "Reverted edits by [[Special:Contribs/Username Needed|Username Needed]] ([[User talk:Username Needed|talk]]) to last version by TritonsRising",
#             "tags": [
#               "mw-rollback"
#             ]
#           },
#           {
#             "revid": 827034352,
#             "parentid": 825715778,
#             "user": "Username Needed",
#             "userid": 31251962,
#             "timestamp": "2018-02-22T11:25:35Z",
#             "size": 104476,
#             "roles": [
#               "main"
#             ],
#             "comment": "Removing link(s) to \"Ultimate (sport)\": Unlinking from deleted article. ([[WP:TW|TW]])",
#             "tags": []
#           },
#           {
#             "revid": 825715778,
#             "parentid": 825130802,
#             "user": "TritonsRising",
#             "userid": 23960444,
#             "timestamp": "2018-02-15T00:08:45Z",
#             "size": 104497,
#             "roles": [
#               "main"
#             ],
#             "comment": "prefer internal links",
#             "tags": []
#           },
#           {
#             "revid": 825130802,
#             "parentid": 825130160,
#             "user": "Larry Hockett",
#             "userid": 15977090,
#             "timestamp": "2018-02-11T17:46:17Z",
#             "size": 104517,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */ ce",
#             "tags": []
#           },
#           {
#             "revid": 825130160,
#             "parentid": 825130113,
#             "user": "67.86.156.30",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2018-02-11T17:41:47Z",
#             "size": 104515,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */",
#             "tags": []
#           },
#           {
#             "revid": 825130113,
#             "parentid": 825048456,
#             "user": "67.86.156.30",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2018-02-11T17:41:28Z",
#             "size": 104514,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */",
#             "tags": []
#           },
#           {
#             "revid": 825048456,
#             "parentid": 825048124,
#             "user": "ElKevbo",
#             "userid": 217538,
#             "timestamp": "2018-02-11T04:58:51Z",
#             "size": 104372,
#             "roles": [
#               "main"
#             ],
#             "comment": "rv link spam",
#             "tags": []
#           },
#           {
#             "revid": 825048124,
#             "parentid": 824733522,
#             "user": "ScrippsEditer",
#             "userid": 33048545,
#             "timestamp": "2018-02-11T04:55:36Z",
#             "size": 104486,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 824733522,
#             "parentid": 824733194,
#             "user": "Larry Hockett",
#             "userid": 15977090,
#             "timestamp": "2018-02-09T04:04:46Z",
#             "size": 104372,
#             "roles": [
#               "main"
#             ],
#             "comment": "Reverted to revision 823935142 by [[Special:Contributions/SJSU Moi|SJSU Moi]] ([[User talk:SJSU Moi|talk]]): Usually we don't cover plans for this kind of thing . ([[WP:TW|TW]])",
#             "tags": [
#               "mw-undo"
#             ]
#           },
#           {
#             "revid": 824733194,
#             "parentid": 824732909,
#             "user": "ScrippsEditer",
#             "userid": 33048545,
#             "timestamp": "2018-02-09T04:01:52Z",
#             "size": 104434,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 824732909,
#             "parentid": 824732602,
#             "user": "ScrippsEditer",
#             "userid": 33048545,
#             "timestamp": "2018-02-09T03:59:01Z",
#             "size": 104440,
#             "roles": [
#               "main"
#             ],
#             "comment": "Moved a category to emphasize page",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 824732602,
#             "parentid": 823935142,
#             "user": "ScrippsEditer",
#             "userid": 33048545,
#             "timestamp": "2018-02-09T03:56:35Z",
#             "size": 104453,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 823935142,
#             "parentid": 823859627,
#             "user": "Sqldf03",
#             "userid": 27711623,
#             "timestamp": "2018-02-04T09:19:22Z",
#             "size": 104372,
#             "roles": [
#               "main"
#             ],
#             "comment": "updated endowment",
#             "tags": []
#           },
#           {
#             "revid": 823859627,
#             "parentid": 823639111,
#             "user": "TritonsRising",
#             "userid": 23960444,
#             "timestamp": "2018-02-03T21:50:51Z",
#             "size": 103805,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 823639111,
#             "parentid": 823607256,
#             "user": "ElKevbo",
#             "userid": 217538,
#             "timestamp": "2018-02-02T14:01:06Z",
#             "size": 103833,
#             "roles": [
#               "main"
#             ],
#             "comment": "neither a source nor a Wikipedia article",
#             "tags": []
#           },
#           {
#             "revid": 823607256,
#             "parentid": 823023333,
#             "user": "Rocummin3",
#             "userid": 32994585,
#             "timestamp": "2018-02-02T08:08:47Z",
#             "size": 103899,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */Added content",
#             "tags": [
#               "mobile edit",
#               "mobile web edit",
#               "canned edit summary"
#             ]
#           },
#           {
#             "revid": 823023333,
#             "parentid": 822328754,
#             "user": "GreenC bot",
#             "userid": 27823944,
#             "timestamp": "2018-01-29T21:32:59Z",
#             "size": 103833,
#             "roles": [
#               "main"
#             ],
#             "comment": "[[User:GreenC/WaybackMedic_2.1|Wayback Medic 2.1]]",
#             "tags": []
#           },
#           {
#             "revid": 822328754,
#             "parentid": 821590878,
#             "user": "67.86.156.30",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2018-01-25T19:14:01Z",
#             "size": 103870,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Departmental rankings */",
#             "tags": []
#           },
#           {
#             "revid": 821590878,
#             "parentid": 821351224,
#             "user": "WereSpielChequers",
#             "userid": 4071608,
#             "timestamp": "2018-01-21T12:06:23Z",
#             "size": 103896,
#             "roles": [
#               "main"
#             ],
#             "comment": "typo",
#             "tags": []
#           },
#           {
#             "revid": 821351224,
#             "parentid": 821345862,
#             "user": "James Allison",
#             "userid": 738200,
#             "timestamp": "2018-01-19T22:56:10Z",
#             "size": 103895,
#             "roles": [
#               "main"
#             ],
#             "comment": "minor reword",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 821345862,
#             "parentid": 821158985,
#             "user": "2600:8801:9202:A700:A47F:33C1:DEEF:31B7",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2018-01-19T22:11:32Z",
#             "size": 103889,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */Added unrecognized alumni",
#             "tags": [
#               "mobile edit",
#               "mobile web edit"
#             ]
#           },
#           {
#             "revid": 821158985,
#             "parentid": 816372667,
#             "user": "Erjohnson22",
#             "userid": 18817284,
#             "timestamp": "2018-01-18T19:27:24Z",
#             "size": 103807,
#             "roles": [
#               "main"
#             ],
#             "comment": "Added academic divisions, updated citation for divisions and schools.",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 816372667,
#             "parentid": 814454078,
#             "user": "12.157.14.126",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-12-20T23:00:51Z",
#             "size": 103787,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Alumni */",
#             "tags": []
#           },
#           {
#             "revid": 814454078,
#             "parentid": 814447068,
#             "user": "Alaney2k",
#             "userid": 209266,
#             "timestamp": "2017-12-08T22:38:34Z",
#             "size": 103740,
#             "roles": [
#               "main"
#             ],
#             "comment": "is \"The Hollywood Reporter\"\", replaced: publisher=Hollywood Reporter \u2192 work=The Hollywood Reporter using [[Project:AWB|AWB]]",
#             "tags": []
#           },
#           {
#             "revid": 814447068,
#             "parentid": 813224128,
#             "user": "67.86.156.30",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-12-08T21:55:27Z",
#             "size": 103745,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Departmental rankings */",
#             "tags": []
#           },
#           {
#             "revid": 813224128,
#             "parentid": 813083818,
#             "user": "InternetArchiveBot",
#             "userid": 27015025,
#             "timestamp": "2017-12-02T14:46:17Z",
#             "size": 103744,
#             "roles": [
#               "main"
#             ],
#             "comment": "Rescuing 6 sources and tagging 0 as dead. #IABot (v1.6.1) ([[User:Balon Greyjoy|Balon Greyjoy]])",
#             "tags": []
#           },
#           {
#             "revid": 813083818,
#             "parentid": 813083312,
#             "user": "James Allison",
#             "userid": 738200,
#             "timestamp": "2017-12-01T17:35:17Z",
#             "size": 102762,
#             "roles": [
#               "main"
#             ],
#             "comment": "notelist",
#             "tags": []
#           },
#           {
#             "revid": 813083312,
#             "parentid": 813080018,
#             "user": "MelanieN",
#             "userid": 1763353,
#             "timestamp": "2017-12-01T17:31:12Z",
#             "size": 102712,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* Athletics */ update, clarify, reorganize; move from level 3 to level 2 section heading",
#             "tags": []
#           },
#           {
#             "revid": 813080018,
#             "parentid": 812506236,
#             "user": "MelanieN",
#             "userid": 1763353,
#             "timestamp": "2017-12-01T17:07:09Z",
#             "size": 102644,
#             "roles": [
#               "main"
#             ],
#             "comment": "clarify: this is the official position, but locally it is still called UCSD",
#             "tags": []
#           },
#           {
#             "revid": 812506236,
#             "parentid": 812451389,
#             "user": "2607:F720:F00:4043:80EF:CB2F:954E:E5BC",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-11-28T05:51:47Z",
#             "size": 102612,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */",
#             "tags": []
#           },
#           {
#             "revid": 812451389,
#             "parentid": 812450936,
#             "user": "Pikachu165",
#             "userid": 31875249,
#             "timestamp": "2017-11-27T22:29:22Z",
#             "size": 102604,
#             "roles": [
#               "main"
#             ],
#             "comment": "Update on UCSD athletics",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 812450936,
#             "parentid": 812450465,
#             "user": "2607:F720:F00:4043:918A:1D3C:3E81:631D",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-11-27T22:26:21Z",
#             "size": 102306,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */",
#             "tags": []
#           },
#           {
#             "revid": 812450465,
#             "parentid": 812449937,
#             "user": "2607:F720:F00:4043:918A:1D3C:3E81:631D",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-11-27T22:22:31Z",
#             "size": 102244,
#             "roles": [
#               "main"
#             ],
#             "comment": "",
#             "tags": []
#           },
#           {
#             "revid": 812449937,
#             "parentid": 812449652,
#             "user": "2607:F720:F00:4043:918A:1D3C:3E81:631D",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-11-27T22:18:10Z",
#             "size": 102283,
#             "roles": [
#               "main"
#             ],
#             "comment": "/* History */",
#             "tags": []
#           },
#           {
#             "revid": 812449652,
#             "parentid": 812440964,
#             "user": "2607:F720:F00:4043:918A:1D3C:3E81:631D",
#             "anon": "",
#             "userid": 0,
#             "timestamp": "2017-11-27T22:16:10Z",
#             "size": 102284,
#             "roles": [
#               "main"
#             ],
#             "comment": "Updated the athletics section as UCSD has moved from Division II to Division I NCAA Big West Conference",
#             "tags": [
#               "visualeditor"
#             ]
#           },
#           {
#             "revid": 812440964,
#             "parentid": 812439364,
#             "user": "Corkythehornetfan",
#             "userid": 16927144,
#             "timestamp": "2017-11-27T21:28:01Z",
#             "size": 101916,
#             "roles": [
#               "main"
#             ],
#             "comment": "no need to mention something in the infobox that's in 2 years",
#             "tags": []
#           }
#         ]
#       }
#     }
#   }
# }

# %% [markdown]
# We have made 8 requests with a max length of 500 each, so we should have 3500-4000 total revisions. We will iterate through those requests, put them each in a pandas dataframe, then concatenate those 8 dataframes into one.

# %%
list_of_dfs = []
for request in requests:
    for page in request['query']['pages'].items():
        list_of_dfs.append(pd.DataFrame(page[1]['revisions']))

# %%
revisions_df = pd.concat(list_of_dfs)

# %%
revisions_df
# Out:
#           revid    parentid               user    userid  \
# 0    1050338887  1050203530        ShelfSkewed   1152308
# 1    1050203530  1050178467         76.88.1.92         0
# 2    1050178467  1048818404       97.115.51.56         0
# 3    1048818404  1047751245           Sgweirdo  39921276
# 4    1047751245  1047400554           PrimeBOT  29463730
# ..          ...         ...                ...       ...
# 174      673033      673031      63.207.143.73         0
# 175      673031      111585                Zoe      2376
# 176      111585      111583                Zoe      2376
# 177      111583   382242594  Conversion script   1226483
# 178   382242594   380631618     129.186.19.xxx         0
#
#                 timestamp    size   roles  \
# 0    2021-10-17T07:12:48Z  160107  [main]
# 1    2021-10-16T11:56:35Z  160079  [main]
# 2    2021-10-16T07:42:29Z  160490  [main]
# 3    2021-10-08T04:53:33Z  160500  [main]
# 4    2021-10-02T11:26:29Z  160508  [main]
# ..                    ...     ...     ...
# 174  2003-02-16T09:51:22Z     528  [main]
# 175  2002-07-06T19:27:04Z     329  [main]
# 176  2002-07-06T19:26:18Z     329  [main]
# 177  2002-02-25T15:51:15Z      75  [main]
# 178  2001-08-19T00:30:27Z      71  [main]
#
#                                                                                                                                                   comment  \
# 0                                                                                                                                             Links fixes
# 1                                                                                                                Updated enrollment figures for Fall 2021
# 2
# 3
# 4    /* External links */[[User:PrimeBOT/24|Task 24]]: removal of a template following [[Wikipedia:Templates_for_discussion/Log/2021_September_24|a TFD]]
# ..                                                                                                                                                    ...
# 174
# 175                                                                                                                                                     *
# 176                                                                                                                                                     *
# 177                                                                                                                                  Automated conversion
# 178                                                                                                                                                     *
#
#                                tags anon commenthidden
# 0                                []  NaN           NaN
# 1    [mobile edit, mobile web edit]                NaN
# 2    [mobile edit, mobile web edit]                NaN
# 3    [mobile edit, mobile web edit]  NaN           NaN
# 4                             [AWB]  NaN           NaN
# ..                              ...  ...           ...
# 174                              []                NaN
# 175                              []  NaN           NaN
# 176                              []  NaN           NaN
# 177                              []  NaN           NaN
# 178                              []                NaN
#
# [3679 rows x 11 columns]

# %% [markdown]
# Convert timestamps to datetime format:

# %%
revisions_df['timestamp_dt'] = pd.to_datetime(revisions_df['timestamp'])

revisions_df = revisions_df.set_index("timestamp_dt")

# %% [markdown]
# Plotting the size of the article in bytes over time:

# %%
fig = revisions_df['size'].plot(figsize=(12,8))
fig.set_ylabel("size in bytes")
fig.set_title("Size (bytes) of UCSD article over time")
# Out:
# Text(0.5, 1.0, 'Size (bytes) of UCSD article over time')

# %% [markdown]
# ### Regex

# %%
import re

# %% [markdown]
# AutoWikiBrowser is used for making automated edits. This regex pattern is looking for any version of "[[WP:AWB", "[[Wikipedia:AWB", "[[Wikipedia:AutoWikiBrowser]]", "[[Project:AWB", etc.

# %%
pattern = "\[\[(Wikipedia|WP|Project):(AWB|AutoWikiBrowser)"
string = "cleanup, [[WP:AWB/T|typo(s) fixed]]: Center"

# %%
result = re.search(pattern, string)
result
# Out:
# <re.Match object; span=(9, 17), match='[[WP:AWB'>

# %%
string = "cleanup, [[WP:BBB/T|typo(s) fixed]]: Center"
result = re.search(pattern, string)
type(result)
# Out:
# NoneType

# %% [markdown]
# We will create a function for parsing these patterns. The early return statements based on conditionals is mostly for performance, as re.search can be more resource intensive.

# %%
def is_awb_regex(comment):
    if comment is None:
        return 0
    if comment is np.nan:
        return 0
    if len(comment) == 0:
        return 0
    
    pattern = "\[\[(Wikipedia|WP|Project):(AWB|AutoWikiBrowser)"
    result = re.search(pattern,comment)
    
    if result is None:
        return 0
    else:
        return 1

# %%
revisions_df['is_awb_regex'] = revisions_df['comment'].apply(is_awb_regex)

# %%
revisions_df[['comment','is_awb_regex']]
# Out:
#                                                                                                                                                                                                        comment  \
# timestamp_dt
# 2021-10-08 04:53:33+00:00
# 2021-10-02 11:26:29+00:00                                 /* External links */[[User:PrimeBOT/24|Task 24]]: removal of a template following [[Wikipedia:Templates_for_discussion/Log/2021_September_24|a TFD]]
# 2021-09-30 17:23:39+00:00           Add: date. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Anas1712 | [[Category:Public universities and colleges in California]] | #UCB_Category 44/71
# 2021-09-28 23:12:25+00:00  Removed Chi Phi as Chapter is no longer active, Removed Sigma Chi as chapter has been suspended from campus and is no longer formally recognized due to Sexual Assault allegations.
# 2021-09-17 01:40:15+00:00                                                                      cleanup, [[WP:AWB/T|typo(s) fixed]]: Center → center, from 2009–2013 → from 2009 to 2013, four year → four-year
# ...                                                                                                                                                                                                        ...
# 2003-02-16 09:51:22+00:00
# 2002-07-06 19:27:04+00:00                                                                                                                                                                                    *
# 2002-07-06 19:26:18+00:00                                                                                                                                                                                    *
# 2002-02-25 15:51:15+00:00                                                                                                                                                                 Automated conversion
# 2001-08-19 00:30:27+00:00                                                                                                                                                                                    *
#
#                            is_awb_regex
# timestamp_dt
# 2021-10-08 04:53:33+00:00             0
# 2021-10-02 11:26:29+00:00             0
# 2021-09-30 17:23:39+00:00             0
# 2021-09-28 23:12:25+00:00             0
# 2021-09-17 01:40:15+00:00             1
# ...                                 ...
# 2003-02-16 09:51:22+00:00             0
# 2002-07-06 19:27:04+00:00             0
# 2002-07-06 19:26:18+00:00             0
# 2002-02-25 15:51:15+00:00             0
# 2001-08-19 00:30:27+00:00             0
#
# [3676 rows x 2 columns]

# %% [markdown]
# But there is also a tags column that has AWB listed. Here is a function to apply on the tags column:

# %%
def is_awb_tags(tags):
    
    if tags is None:
        return 0
    if tags is np.nan:
        return 0
    
    try:
        tag0 = tags[0]
    except Exception:   # If there is no first element
        return 0
    
    if tag0 == "AWB":
        return 1
    else:
        return 0

# %%
revisions_df['is_awb_tags'] = revisions_df['tags'].apply(is_awb_tags)

# %% [markdown]
# If both our regex and the tags field are perfect and accurate, then the correlation should be 1.

# %%
pd.DataFrame(revisions_df[['is_awb_regex','is_awb_tags']].corr())
# Out:
#               is_awb_regex  is_awb_tags
# is_awb_regex       1.00000      0.15199
# is_awb_tags        0.15199      1.00000

# %% [markdown]
# Oh no! What is going on?

# %%
pd.DataFrame(revisions_df[['is_awb_regex','is_awb_tags']].value_counts())
# Out:
#                              0
# is_awb_regex is_awb_tags
# 0            0            3610
# 1            0              47
# 0            1              14
# 1            1               5

# %%
revisions_df[['comment','is_awb_regex','is_awb_tags']].query("is_awb_regex != is_awb_tags")
# Out:
#                                                                                                                                                                                                                   comment  \
# timestamp_dt
# 2021-10-02 11:26:29+00:00                                            /* External links */[[User:PrimeBOT/24|Task 24]]: removal of a template following [[Wikipedia:Templates_for_discussion/Log/2021_September_24|a TFD]]
# 2020-12-27 02:36:34+00:00                                                                                                       [[User:Monkbot/task 18|Task 18 (cosmetic)]]: eval 202 templates: hyphenate params (146×);
# 2020-11-29 23:08:13+00:00                                     [[User:Monkbot/task 18|Task 18 (cosmetic)]]: eval 203 templates: del empty params (27×); hyphenate params (16×); del |ref=harv (6×); del |url-status= (4×);
# 2020-08-28 12:36:00+00:00                                                                                                                                                              remove extraneous definite article
# 2020-05-30 12:33:57+00:00                                                                                                                                                    /* History */Journal cites:, added 1 Bibcode
# ...                                                                                                                                                                                                                   ...
# 2007-04-18 03:50:40+00:00                                                                                                                      clean up, Replaced: is comprised of → comprises  using [[Project:AWB|AWB]]
# 2007-02-10 02:10:27+00:00  Repairing link to disambiguation page - [[Wikipedia:Disambiguation pages with links|You can help!]] , Replaced: [[USC]] → [[University of Southern California|USC]]  using [[Project:AWB|AWB]]
# 2006-10-24 22:37:40+00:00                                                                                                                       clean up, Replaced: [[USA]] → [[United States|USA]]  using [[WP:AWB|AWB]]
# 2006-08-27 12:03:41+00:00                                                                      [[WP:RETF|mboverload's RegExTypoFix]] mod [[User:Guinnog]], Replaced: most well known →  best-known,  using [[WP:AWB|AWB]]
# 2006-05-23 12:36:26+00:00                                                                                                                                           Unicodifying  using [[Wikipedia:AutoWikiBrowser|AWB]]
#
#                            is_awb_regex  is_awb_tags
# timestamp_dt
# 2021-10-02 11:26:29+00:00             0            1
# 2020-12-27 02:36:34+00:00             0            1
# 2020-11-29 23:08:13+00:00             0            1
# 2020-08-28 12:36:00+00:00             0            1
# 2020-05-30 12:33:57+00:00             0            1
# ...                                 ...          ...
# 2007-04-18 03:50:40+00:00             1            0
# 2007-02-10 02:10:27+00:00             1            0
# 2006-10-24 22:37:40+00:00             1            0
# 2006-08-27 12:03:41+00:00             1            0
# 2006-05-23 12:36:26+00:00             1            0
#
# [61 rows x 3 columns]

# %%
revisions_df[['comment','is_awb_regex','is_awb_tags']].query("is_awb_tags == is_awb_regex")
# Out:
#                                                                                                                                                                                                        comment  \
# timestamp_dt
# 2021-10-08 04:53:33+00:00
# 2021-09-30 17:23:39+00:00           Add: date. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Anas1712 | [[Category:Public universities and colleges in California]] | #UCB_Category 44/71
# 2021-09-28 23:12:25+00:00  Removed Chi Phi as Chapter is no longer active, Removed Sigma Chi as chapter has been suspended from campus and is no longer formally recognized due to Sexual Assault allegations.
# 2021-09-17 01:40:15+00:00                                                                      cleanup, [[WP:AWB/T|typo(s) fixed]]: Center → center, from 2009–2013 → from 2009 to 2013, four year → four-year
# 2021-09-16 21:34:39+00:00                                                                                                                            Rmv undefined, unsupported, deprecated infobox parameters
# ...                                                                                                                                                                                                        ...
# 2003-02-16 09:51:22+00:00
# 2002-07-06 19:27:04+00:00                                                                                                                                                                                    *
# 2002-07-06 19:26:18+00:00                                                                                                                                                                                    *
# 2002-02-25 15:51:15+00:00                                                                                                                                                                 Automated conversion
# 2001-08-19 00:30:27+00:00                                                                                                                                                                                    *
#
#                            is_awb_regex  is_awb_tags
# timestamp_dt
# 2021-10-08 04:53:33+00:00             0            0
# 2021-09-30 17:23:39+00:00             0            0
# 2021-09-28 23:12:25+00:00             0            0
# 2021-09-17 01:40:15+00:00             1            1
# 2021-09-16 21:34:39+00:00             0            0
# ...                                 ...          ...
# 2003-02-16 09:51:22+00:00             0            0
# 2002-07-06 19:27:04+00:00             0            0
# 2002-07-06 19:26:18+00:00             0            0
# 2002-02-25 15:51:15+00:00             0            0
# 2001-08-19 00:30:27+00:00             0            0
#
# [3615 rows x 3 columns]

# %% [markdown]
# ### Rolling averages
#
# Proportion of is_awb_regex over various windows. See documentation at: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

# %%
revisions_df['is_awb_regex'].rolling("7D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
revisions_df['is_awb_regex'].rolling("30D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
revisions_df['is_awb_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %% [markdown]
# ### Assignment part 1
#
# Find an article with at least 20,000 revisions. How has the proportion of users editing from mobile web devices (according to the tags) changed over time? Note that there can be multiple tags in the column.

# %%
mj_revs = session.get(action="query",
                        prop="revisions",
                        titles="Michael Jackson",
                        rvprop="ids|timestamp|comment|user|userid|size|tags|roles",
                        rvlimit=500,
                        continuation=True)

# %%
type(mj_revs)
# Out:
# generator

# %%
mj_requests = []
for request in mj_revs:
    mj_requests.append(request)

# %%
len(mj_requests)
# Out:
# 64

# %%
list_of_dfs_1 = []
for request in mj_requests:
    for page in request['query']['pages'].items():
        list_of_dfs_1.append(pd.DataFrame(page[1]['revisions']))

# %%
revisions_df_1 = pd.concat(list_of_dfs_1)

# %%
revisions_df_1['timestamp_dt'] = pd.to_datetime(revisions_df_1['timestamp'])

revisions_df_1 = revisions_df_1.set_index("timestamp_dt")

# %%
revisions_df_1
# Out:
#                                 revid    parentid               user  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00  1050325505  1050299558          Jimcastor
# 2021-10-17 00:46:31+00:00  1050299558  1049812279               Slp1
# 2021-10-14 00:22:15+00:00  1049812279  1049812002               ILIL
# 2021-10-14 00:19:44+00:00  1049812002  1049811970            Salvabl
# 2021-10-14 00:19:31+00:00  1049811970  1049811596           SNUGGUMS
# ...                               ...         ...                ...
# 2002-07-03 17:59:22+00:00      121293      109398         MarkAtwood
# 2002-02-25 15:51:15+00:00      109398   345215415  Conversion script
# 2001-11-14 17:38:44+00:00   345215415   345143092           Dmerrill
# 2001-11-14 17:35:37+00:00      267797      267796           Dmerrill
# 2001-10-25 07:48:17+00:00      267796           0          Aristotle
#
#                                userid             timestamp    size   roles  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00  34511366.0  2021-10-17T04:55:14Z  243836  [main]
# 2021-10-17 00:46:31+00:00   1234297.0  2021-10-17T00:46:31Z  243839  [main]
# 2021-10-14 00:22:15+00:00  18934599.0  2021-10-14T00:22:15Z  243836  [main]
# 2021-10-14 00:19:44+00:00  22422642.0  2021-10-14T00:19:44Z  243746  [main]
# 2021-10-14 00:19:31+00:00  19269270.0  2021-10-14T00:19:31Z  243745  [main]
# ...                               ...                   ...     ...     ...
# 2002-07-03 17:59:22+00:00       539.0  2002-07-03T17:59:22Z    2326  [main]
# 2002-02-25 15:51:15+00:00   1226483.0  2002-02-25T15:51:15Z    2314  [main]
# 2001-11-14 17:38:44+00:00   1699319.0  2001-11-14T17:38:44Z    2302  [main]
# 2001-11-14 17:35:37+00:00   1699319.0  2001-11-14T17:35:37Z    2321  [main]
# 2001-10-25 07:48:17+00:00  32609872.0  2001-10-25T07:48:17Z    2307  [main]
#
#                                                                                                                                          comment  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00                            source clearly says  Murray administered propofol and mixed it with lorazepam and midazolam
# 2021-10-17 00:46:31+00:00                                                                                       /* Death */ what the source says
# 2021-10-14 00:22:15+00:00  /* top */ trying again to link [[List of Michael Jackson records and achievements]], seems very valuable for the lead
# 2021-10-14 00:19:44+00:00                                                                                                                    fix
# 2021-10-14 00:19:31+00:00                                                                                                           Cleaner text
# ...                                                                                                                                          ...
# 2002-07-03 17:59:22+00:00                                                                                                                      *
# 2002-02-25 15:51:15+00:00                                                                                                   Automated conversion
# 2001-11-14 17:38:44+00:00                                                                                        fix link to match GO's redirect
# 2001-11-14 17:35:37+00:00                                                                                                         link pop music
# 2001-10-25 07:48:17+00:00                                                                                                                      *
#
#                                                   tags anon commenthidden  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00           [mw-manual-revert]  NaN           NaN
# 2021-10-17 00:46:31+00:00  [visualeditor, mw-reverted]  NaN           NaN
# 2021-10-14 00:22:15+00:00                           []  NaN           NaN
# 2021-10-14 00:19:44+00:00                           []  NaN           NaN
# 2021-10-14 00:19:31+00:00                           []  NaN           NaN
# ...                                                ...  ...           ...
# 2002-07-03 17:59:22+00:00                           []  NaN           NaN
# 2002-02-25 15:51:15+00:00                           []  NaN           NaN
# 2001-11-14 17:38:44+00:00                           []  NaN           NaN
# 2001-11-14 17:35:37+00:00                           []  NaN           NaN
# 2001-10-25 07:48:17+00:00                           []  NaN           NaN
#
#                           userhidden suppressed
# timestamp_dt
# 2021-10-17 04:55:14+00:00        NaN        NaN
# 2021-10-17 00:46:31+00:00        NaN        NaN
# 2021-10-14 00:22:15+00:00        NaN        NaN
# 2021-10-14 00:19:44+00:00        NaN        NaN
# 2021-10-14 00:19:31+00:00        NaN        NaN
# ...                              ...        ...
# 2002-07-03 17:59:22+00:00        NaN        NaN
# 2002-02-25 15:51:15+00:00        NaN        NaN
# 2001-11-14 17:38:44+00:00        NaN        NaN
# 2001-11-14 17:35:37+00:00        NaN        NaN
# 2001-10-25 07:48:17+00:00        NaN        NaN
#
# [31633 rows x 13 columns]

# %%
revisions_df_1.tags.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                                                    30718
# [visualeditor]                                                          340
# [mobile edit, mobile web edit]                                          164
# [mw-undo]                                                               120
# [visualeditor-wikitext]                                                  58
# [mw-reverted]                                                            45
# [mobile edit, mobile app edit]                                           38
# [AWB]                                                                    27
# [mw-undo, twinkle]                                                       22
# [mobile edit]                                                            15
# [mobile edit, mobile web edit, advanced mobile edit]                     10
# [mw-rollback]                                                             9
# [visualeditor, mw-reverted]                                               8
# [visualeditor-switched]                                                   6
# [mobile edit, mobile app edit, android app edit]                          6
# [mobile edit, mobile web edit, visualeditor]                              5
# [mw-manual-revert]                                                        4
# [OAuth CID: 99]                                                           4
# [mw-undo, RedWarn, mw-reverted]                                           3
# [mw-manual-revert, mw-reverted]                                           3
# [mw-undo, mw-reverted]                                                    3
# [mobile edit, mobile app edit, ios app edit]                              3
# [visualeditor, nowiki added]                                              2
# [possibly non-minor edit]                                                 2
# [visualeditor, visualeditor-needcheck]                                    2
# [WPCleaner]                                                               2
# [OAuth CID: 678]                                                          2
# [mobile edit, mobile web edit, advanced mobile edit, mw-reverted]         2
# [huggle, mw-rollback]                                                     1
# [mw-rollback, mw-reverted]                                                1
# [mw-add-media, mw-remove-media]                                           1
# [mw-reverted, mw-add-media, mw-remove-media]                              1
# [mw-undo, RedWarn]                                                        1
# [mobile edit, mobile web edit, visualeditor, advanced mobile edit]        1
# [visualeditor, mw-add-media]                                              1
# [mobile edit, mobile web edit, mw-reverted]                               1
# [mw-undo, twinkle, mw-reverted]                                           1
# [mw-undo, twinkle, mw-add-media, mw-remove-media]                         1
# Name: tags, dtype: int64

# %%
revisions_df_1['mobile_web'] = revisions_df_1['tags'].apply(lambda x: 1 if 'mobile web edit' in x else 0)

# %%
revisions_df_1['all_dev'] = 1

# %%
revisions_df_1
# Out:
#                                 revid    parentid               user  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00  1050325505  1050299558          Jimcastor
# 2021-10-17 00:46:31+00:00  1050299558  1049812279               Slp1
# 2021-10-14 00:22:15+00:00  1049812279  1049812002               ILIL
# 2021-10-14 00:19:44+00:00  1049812002  1049811970            Salvabl
# 2021-10-14 00:19:31+00:00  1049811970  1049811596           SNUGGUMS
# ...                               ...         ...                ...
# 2002-07-03 17:59:22+00:00      121293      109398         MarkAtwood
# 2002-02-25 15:51:15+00:00      109398   345215415  Conversion script
# 2001-11-14 17:38:44+00:00   345215415   345143092           Dmerrill
# 2001-11-14 17:35:37+00:00      267797      267796           Dmerrill
# 2001-10-25 07:48:17+00:00      267796           0          Aristotle
#
#                                userid             timestamp    size   roles  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00  34511366.0  2021-10-17T04:55:14Z  243836  [main]
# 2021-10-17 00:46:31+00:00   1234297.0  2021-10-17T00:46:31Z  243839  [main]
# 2021-10-14 00:22:15+00:00  18934599.0  2021-10-14T00:22:15Z  243836  [main]
# 2021-10-14 00:19:44+00:00  22422642.0  2021-10-14T00:19:44Z  243746  [main]
# 2021-10-14 00:19:31+00:00  19269270.0  2021-10-14T00:19:31Z  243745  [main]
# ...                               ...                   ...     ...     ...
# 2002-07-03 17:59:22+00:00       539.0  2002-07-03T17:59:22Z    2326  [main]
# 2002-02-25 15:51:15+00:00   1226483.0  2002-02-25T15:51:15Z    2314  [main]
# 2001-11-14 17:38:44+00:00   1699319.0  2001-11-14T17:38:44Z    2302  [main]
# 2001-11-14 17:35:37+00:00   1699319.0  2001-11-14T17:35:37Z    2321  [main]
# 2001-10-25 07:48:17+00:00  32609872.0  2001-10-25T07:48:17Z    2307  [main]
#
#                                                                                                                                          comment  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00                            source clearly says  Murray administered propofol and mixed it with lorazepam and midazolam
# 2021-10-17 00:46:31+00:00                                                                                       /* Death */ what the source says
# 2021-10-14 00:22:15+00:00  /* top */ trying again to link [[List of Michael Jackson records and achievements]], seems very valuable for the lead
# 2021-10-14 00:19:44+00:00                                                                                                                    fix
# 2021-10-14 00:19:31+00:00                                                                                                           Cleaner text
# ...                                                                                                                                          ...
# 2002-07-03 17:59:22+00:00                                                                                                                      *
# 2002-02-25 15:51:15+00:00                                                                                                   Automated conversion
# 2001-11-14 17:38:44+00:00                                                                                        fix link to match GO's redirect
# 2001-11-14 17:35:37+00:00                                                                                                         link pop music
# 2001-10-25 07:48:17+00:00                                                                                                                      *
#
#                                                   tags anon commenthidden  \
# timestamp_dt
# 2021-10-17 04:55:14+00:00           [mw-manual-revert]  NaN           NaN
# 2021-10-17 00:46:31+00:00  [visualeditor, mw-reverted]  NaN           NaN
# 2021-10-14 00:22:15+00:00                           []  NaN           NaN
# 2021-10-14 00:19:44+00:00                           []  NaN           NaN
# 2021-10-14 00:19:31+00:00                           []  NaN           NaN
# ...                                                ...  ...           ...
# 2002-07-03 17:59:22+00:00                           []  NaN           NaN
# 2002-02-25 15:51:15+00:00                           []  NaN           NaN
# 2001-11-14 17:38:44+00:00                           []  NaN           NaN
# 2001-11-14 17:35:37+00:00                           []  NaN           NaN
# 2001-10-25 07:48:17+00:00                           []  NaN           NaN
#
#                           userhidden suppressed  mobile_web  all_dev
# timestamp_dt
# 2021-10-17 04:55:14+00:00        NaN        NaN           0        1
# 2021-10-17 00:46:31+00:00        NaN        NaN           0        1
# 2021-10-14 00:22:15+00:00        NaN        NaN           0        1
# 2021-10-14 00:19:44+00:00        NaN        NaN           0        1
# 2021-10-14 00:19:31+00:00        NaN        NaN           0        1
# ...                              ...        ...         ...      ...
# 2002-07-03 17:59:22+00:00        NaN        NaN           0        1
# 2002-02-25 15:51:15+00:00        NaN        NaN           0        1
# 2001-11-14 17:38:44+00:00        NaN        NaN           0        1
# 2001-11-14 17:35:37+00:00        NaN        NaN           0        1
# 2001-10-25 07:48:17+00:00        NaN        NaN           0        1
#
# [31633 rows x 15 columns]

# %%
rev_df_reversed = revisions_df_1.iloc[::-1]
rev_df_reversed["mobile_web_cumul"] = rev_df_reversed["mobile_web"].cumsum()
rev_df_reversed["all_dev_cumul"] = rev_df_reversed["all_dev"].cumsum()
rev_df_reversed["mobile_web_prop"] = rev_df_reversed["mobile_web_cumul"].div(rev_df_reversed["all_dev_cumul"])
rev_df_reversed
# Out:
# <ipython-input-51-e505a87f5d11>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed["mobile_web_cumul"] = rev_df_reversed["mobile_web"].cumsum()
# <ipython-input-51-e505a87f5d11>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed["all_dev_cumul"] = rev_df_reversed["all_dev"].cumsum()
# <ipython-input-51-e505a87f5d11>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed["mobile_web_prop"] = rev_df_reversed["mobile_web_cumul"].div(rev_df_reversed["all_dev_cumul"])
#                                 revid    parentid               user  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00      267796           0          Aristotle
# 2001-11-14 17:35:37+00:00      267797      267796           Dmerrill
# 2001-11-14 17:38:44+00:00   345215415   345143092           Dmerrill
# 2002-02-25 15:51:15+00:00      109398   345215415  Conversion script
# 2002-07-03 17:59:22+00:00      121293      109398         MarkAtwood
# ...                               ...         ...                ...
# 2021-10-14 00:19:31+00:00  1049811970  1049811596           SNUGGUMS
# 2021-10-14 00:19:44+00:00  1049812002  1049811970            Salvabl
# 2021-10-14 00:22:15+00:00  1049812279  1049812002               ILIL
# 2021-10-17 00:46:31+00:00  1050299558  1049812279               Slp1
# 2021-10-17 04:55:14+00:00  1050325505  1050299558          Jimcastor
#
#                                userid             timestamp    size   roles  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00  32609872.0  2001-10-25T07:48:17Z    2307  [main]
# 2001-11-14 17:35:37+00:00   1699319.0  2001-11-14T17:35:37Z    2321  [main]
# 2001-11-14 17:38:44+00:00   1699319.0  2001-11-14T17:38:44Z    2302  [main]
# 2002-02-25 15:51:15+00:00   1226483.0  2002-02-25T15:51:15Z    2314  [main]
# 2002-07-03 17:59:22+00:00       539.0  2002-07-03T17:59:22Z    2326  [main]
# ...                               ...                   ...     ...     ...
# 2021-10-14 00:19:31+00:00  19269270.0  2021-10-14T00:19:31Z  243745  [main]
# 2021-10-14 00:19:44+00:00  22422642.0  2021-10-14T00:19:44Z  243746  [main]
# 2021-10-14 00:22:15+00:00  18934599.0  2021-10-14T00:22:15Z  243836  [main]
# 2021-10-17 00:46:31+00:00   1234297.0  2021-10-17T00:46:31Z  243839  [main]
# 2021-10-17 04:55:14+00:00  34511366.0  2021-10-17T04:55:14Z  243836  [main]
#
#                                                                                                                                          comment  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                                                                                                                      *
# 2001-11-14 17:35:37+00:00                                                                                                         link pop music
# 2001-11-14 17:38:44+00:00                                                                                        fix link to match GO's redirect
# 2002-02-25 15:51:15+00:00                                                                                                   Automated conversion
# 2002-07-03 17:59:22+00:00                                                                                                                      *
# ...                                                                                                                                          ...
# 2021-10-14 00:19:31+00:00                                                                                                           Cleaner text
# 2021-10-14 00:19:44+00:00                                                                                                                    fix
# 2021-10-14 00:22:15+00:00  /* top */ trying again to link [[List of Michael Jackson records and achievements]], seems very valuable for the lead
# 2021-10-17 00:46:31+00:00                                                                                       /* Death */ what the source says
# 2021-10-17 04:55:14+00:00                            source clearly says  Murray administered propofol and mixed it with lorazepam and midazolam
#
#                                                   tags anon commenthidden  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                           []  NaN           NaN
# 2001-11-14 17:35:37+00:00                           []  NaN           NaN
# 2001-11-14 17:38:44+00:00                           []  NaN           NaN
# 2002-02-25 15:51:15+00:00                           []  NaN           NaN
# 2002-07-03 17:59:22+00:00                           []  NaN           NaN
# ...                                                ...  ...           ...
# 2021-10-14 00:19:31+00:00                           []  NaN           NaN
# 2021-10-14 00:19:44+00:00                           []  NaN           NaN
# 2021-10-14 00:22:15+00:00                           []  NaN           NaN
# 2021-10-17 00:46:31+00:00  [visualeditor, mw-reverted]  NaN           NaN
# 2021-10-17 04:55:14+00:00           [mw-manual-revert]  NaN           NaN
#
#                           userhidden suppressed  mobile_web  all_dev  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00        NaN        NaN           0        1
# 2001-11-14 17:35:37+00:00        NaN        NaN           0        1
# 2001-11-14 17:38:44+00:00        NaN        NaN           0        1
# 2002-02-25 15:51:15+00:00        NaN        NaN           0        1
# 2002-07-03 17:59:22+00:00        NaN        NaN           0        1
# ...                              ...        ...         ...      ...
# 2021-10-14 00:19:31+00:00        NaN        NaN           0        1
# 2021-10-14 00:19:44+00:00        NaN        NaN           0        1
# 2021-10-14 00:22:15+00:00        NaN        NaN           0        1
# 2021-10-17 00:46:31+00:00        NaN        NaN           0        1
# 2021-10-17 04:55:14+00:00        NaN        NaN           0        1
#
#                            mobile_web_cumul  all_dev_cumul  mobile_web_prop
# timestamp_dt
# 2001-10-25 07:48:17+00:00                 0              1         0.000000
# 2001-11-14 17:35:37+00:00                 0              2         0.000000
# 2001-11-14 17:38:44+00:00                 0              3         0.000000
# 2002-02-25 15:51:15+00:00                 0              4         0.000000
# 2002-07-03 17:59:22+00:00                 0              5         0.000000
# ...                                     ...            ...              ...
# 2021-10-14 00:19:31+00:00               183          31629         0.005786
# 2021-10-14 00:19:44+00:00               183          31630         0.005786
# 2021-10-14 00:22:15+00:00               183          31631         0.005785
# 2021-10-17 00:46:31+00:00               183          31632         0.005785
# 2021-10-17 04:55:14+00:00               183          31633         0.005785
#
# [31633 rows x 18 columns]

# %%
fig = rev_df_reversed['mobile_web_prop'].plot(figsize=(12,8))
fig.set_ylabel("Proportion of Mobile Web Edits")
fig.set_title("Proportion of Mobile Web Edits of Michael Jackson article over time")
# Out:
# Text(0.5, 1.0, 'Proportion of Mobile Web Edits of Michael Jackson article over time')

# %% [markdown]
# ### Assignment part 2
#
# See the regexes and tags at: https://meta.wikimedia.org/wiki/MediaWiki:XTools-AutoEdits.json
#
# Implement functions that can be applied to the revisions_df dataframe to create new columns based on the following tools:
#
# - global: Huggle, Undo
# - en: Generic rollback, undo
# - en.wikipedia.org: Huggle, Bot revert, Twinkle
#
# For the article you chose in part 1, how has the proportion of tool-assisted edits changed over time?

# %%
def is__regex(comment, pattern):
    if comment is None:
        return 0
    if comment is np.nan:
        return 0
    if len(comment) == 0:
        return 0
    
    result = re.search(pattern,comment)
    
    if result is None:
        return 0
    else:
        return 1
    
    
def is__tags(tags, tool):
    
    if tags is None:
        return 0
    if tags is np.nan:
        return 0
    
    try:
        tag0 = tags[0]
    except Exception:   # If there is no first element
        return 0
    
    if tag0 == tool:
        return 1
    else:
        return 0
    
Huggle_pat = "\(\[\[WP:HG"
# is_huggle_reg = is__regex(comment, Huggle_pat)

Huggle_tag = "huggle"
# is_huggle_tags = is__tags(tags, Huggle_tag)

Undo_tag = "mw-undo"
# is_Undo_tags = is__tags(tags, Undo_tag)

en_generic_rollback_reg = "^(\[\[Help:Reverting\|Reverted\]\]|Reverted) edits by \[\[Special:(Contribs|Contributions)\/.*?\|.*?\]\]( \(\[\[User talk:.*?\|talk\]\]\))? to last (version|revision) by"

en_undo_reg = "^(Undid|Undo|\[\[WP:UNDO\|Undid\]\]) revision \d+ by \[\[Special:(Contribs|Contributions)\/.*?\|.*?\]\]"

en_wikipedia_huggle_revert = "Reverted edits by.*?WP:HG"
en_wikipedia_botrevert_reg = "^Reverting possible (vandalism|test edit).*by.*\(Bot|BOT( EDIT)?\)$|^BOT (- )?(Reverted edits? by|rv)|^vandalism from \[\[.*?\(\d+\) - reverted"
en_wikipedia_twinkle_reg = "(Wikipedia|WP):(TW|TWINKLE|Twinkle|FRIENDLY)"
en_wikipedia_twinkle_tag = "twinkle"

# %%
rev_df_reversed['is_huggle_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,Huggle_pat))
rev_df_reversed['is_huggle_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,Huggle_tag))
rev_df_reversed['is_undo_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,Undo_tag))
rev_df_reversed['is_en_generic_rollback_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_generic_rollback_reg))
rev_df_reversed['is_en_undo_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_undo_reg))
rev_df_reversed['is_en_wikipedia_huggle_revert'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_huggle_revert))
rev_df_reversed['is_en_wikipedia_botrevert_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_botrevert_reg))
rev_df_reversed['is_en_wikipedia_twinkle_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_twinkle_reg))
rev_df_reversed['is_en_wikipedia_twinkle_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,en_wikipedia_twinkle_tag))                                                                                     




rev_df_reversed
# Out:
# <ipython-input-70-a9e85cc7d51f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_huggle_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,Huggle_pat))
# <ipython-input-70-a9e85cc7d51f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_huggle_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,Huggle_tag))
# <ipython-input-70-a9e85cc7d51f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_undo_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,Undo_tag))
# <ipython-input-70-a9e85cc7d51f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_generic_rollback_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_generic_rollback_reg))
# <ipython-input-70-a9e85cc7d51f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_undo_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_undo_reg))
# <ipython-input-70-a9e85cc7d51f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_wikipedia_huggle_revert'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_huggle_revert))
# <ipython-input-70-a9e85cc7d51f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_wikipedia_botrevert_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_botrevert_reg))
# <ipython-input-70-a9e85cc7d51f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_wikipedia_twinkle_regex'] = rev_df_reversed['comment'].apply(lambda x: is__regex(x,en_wikipedia_twinkle_reg))
# <ipython-input-70-a9e85cc7d51f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df_reversed['is_en_wikipedia_twinkle_tags'] = rev_df_reversed['tags'].apply(lambda x: is__tags(x,en_wikipedia_twinkle_tag))
#                                 revid    parentid               user  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00      267796           0          Aristotle
# 2001-11-14 17:35:37+00:00      267797      267796           Dmerrill
# 2001-11-14 17:38:44+00:00   345215415   345143092           Dmerrill
# 2002-02-25 15:51:15+00:00      109398   345215415  Conversion script
# 2002-07-03 17:59:22+00:00      121293      109398         MarkAtwood
# ...                               ...         ...                ...
# 2021-10-14 00:19:31+00:00  1049811970  1049811596           SNUGGUMS
# 2021-10-14 00:19:44+00:00  1049812002  1049811970            Salvabl
# 2021-10-14 00:22:15+00:00  1049812279  1049812002               ILIL
# 2021-10-17 00:46:31+00:00  1050299558  1049812279               Slp1
# 2021-10-17 04:55:14+00:00  1050325505  1050299558          Jimcastor
#
#                                userid             timestamp    size   roles  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00  32609872.0  2001-10-25T07:48:17Z    2307  [main]
# 2001-11-14 17:35:37+00:00   1699319.0  2001-11-14T17:35:37Z    2321  [main]
# 2001-11-14 17:38:44+00:00   1699319.0  2001-11-14T17:38:44Z    2302  [main]
# 2002-02-25 15:51:15+00:00   1226483.0  2002-02-25T15:51:15Z    2314  [main]
# 2002-07-03 17:59:22+00:00       539.0  2002-07-03T17:59:22Z    2326  [main]
# ...                               ...                   ...     ...     ...
# 2021-10-14 00:19:31+00:00  19269270.0  2021-10-14T00:19:31Z  243745  [main]
# 2021-10-14 00:19:44+00:00  22422642.0  2021-10-14T00:19:44Z  243746  [main]
# 2021-10-14 00:22:15+00:00  18934599.0  2021-10-14T00:22:15Z  243836  [main]
# 2021-10-17 00:46:31+00:00   1234297.0  2021-10-17T00:46:31Z  243839  [main]
# 2021-10-17 04:55:14+00:00  34511366.0  2021-10-17T04:55:14Z  243836  [main]
#
#                                                                                                                                          comment  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                                                                                                                      *
# 2001-11-14 17:35:37+00:00                                                                                                         link pop music
# 2001-11-14 17:38:44+00:00                                                                                        fix link to match GO's redirect
# 2002-02-25 15:51:15+00:00                                                                                                   Automated conversion
# 2002-07-03 17:59:22+00:00                                                                                                                      *
# ...                                                                                                                                          ...
# 2021-10-14 00:19:31+00:00                                                                                                           Cleaner text
# 2021-10-14 00:19:44+00:00                                                                                                                    fix
# 2021-10-14 00:22:15+00:00  /* top */ trying again to link [[List of Michael Jackson records and achievements]], seems very valuable for the lead
# 2021-10-17 00:46:31+00:00                                                                                       /* Death */ what the source says
# 2021-10-17 04:55:14+00:00                            source clearly says  Murray administered propofol and mixed it with lorazepam and midazolam
#
#                                                   tags anon  ...  \
# timestamp_dt                                                 ...
# 2001-10-25 07:48:17+00:00                           []  NaN  ...
# 2001-11-14 17:35:37+00:00                           []  NaN  ...
# 2001-11-14 17:38:44+00:00                           []  NaN  ...
# 2002-02-25 15:51:15+00:00                           []  NaN  ...
# 2002-07-03 17:59:22+00:00                           []  NaN  ...
# ...                                                ...  ...  ...
# 2021-10-14 00:19:31+00:00                           []  NaN  ...
# 2021-10-14 00:19:44+00:00                           []  NaN  ...
# 2021-10-14 00:22:15+00:00                           []  NaN  ...
# 2021-10-17 00:46:31+00:00  [visualeditor, mw-reverted]  NaN  ...
# 2021-10-17 04:55:14+00:00           [mw-manual-revert]  NaN  ...
#
#                           mobile_web_prop is_huggle_regex is_huggle_tags  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00        0.000000               0              0
# 2001-11-14 17:35:37+00:00        0.000000               0              0
# 2001-11-14 17:38:44+00:00        0.000000               0              0
# 2002-02-25 15:51:15+00:00        0.000000               0              0
# 2002-07-03 17:59:22+00:00        0.000000               0              0
# ...                                   ...             ...            ...
# 2021-10-14 00:19:31+00:00        0.005786               0              0
# 2021-10-14 00:19:44+00:00        0.005786               0              0
# 2021-10-14 00:22:15+00:00        0.005785               0              0
# 2021-10-17 00:46:31+00:00        0.005785               0              0
# 2021-10-17 04:55:14+00:00        0.005785               0              0
#
#                            is_undo_tags  is_en_generic_rollback_regex  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00             0                             0
# 2001-11-14 17:35:37+00:00             0                             0
# 2001-11-14 17:38:44+00:00             0                             0
# 2002-02-25 15:51:15+00:00             0                             0
# 2002-07-03 17:59:22+00:00             0                             0
# ...                                 ...                           ...
# 2021-10-14 00:19:31+00:00             0                             0
# 2021-10-14 00:19:44+00:00             0                             0
# 2021-10-14 00:22:15+00:00             0                             0
# 2021-10-17 00:46:31+00:00             0                             0
# 2021-10-17 04:55:14+00:00             0                             0
#
#                            is_en_undo_regex  is_en_wikipedia_huggle_revert  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                 0                              0
# 2001-11-14 17:35:37+00:00                 0                              0
# 2001-11-14 17:38:44+00:00                 0                              0
# 2002-02-25 15:51:15+00:00                 0                              0
# 2002-07-03 17:59:22+00:00                 0                              0
# ...                                     ...                            ...
# 2021-10-14 00:19:31+00:00                 0                              0
# 2021-10-14 00:19:44+00:00                 0                              0
# 2021-10-14 00:22:15+00:00                 0                              0
# 2021-10-17 00:46:31+00:00                 0                              0
# 2021-10-17 04:55:14+00:00                 0                              0
#
#                            is_en_wikipedia_botrevert_regex  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                                0
# 2001-11-14 17:35:37+00:00                                0
# 2001-11-14 17:38:44+00:00                                0
# 2002-02-25 15:51:15+00:00                                0
# 2002-07-03 17:59:22+00:00                                0
# ...                                                    ...
# 2021-10-14 00:19:31+00:00                                0
# 2021-10-14 00:19:44+00:00                                0
# 2021-10-14 00:22:15+00:00                                0
# 2021-10-17 00:46:31+00:00                                0
# 2021-10-17 04:55:14+00:00                                0
#
#                            is_en_wikipedia_twinkle_regex  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                              0
# 2001-11-14 17:35:37+00:00                              0
# 2001-11-14 17:38:44+00:00                              0
# 2002-02-25 15:51:15+00:00                              0
# 2002-07-03 17:59:22+00:00                              0
# ...                                                  ...
# 2021-10-14 00:19:31+00:00                              0
# 2021-10-14 00:19:44+00:00                              0
# 2021-10-14 00:22:15+00:00                              0
# 2021-10-17 00:46:31+00:00                              0
# 2021-10-17 04:55:14+00:00                              0
#
#                            is_en_wikipedia_twinkle_tags
# timestamp_dt
# 2001-10-25 07:48:17+00:00                             0
# 2001-11-14 17:35:37+00:00                             0
# 2001-11-14 17:38:44+00:00                             0
# 2002-02-25 15:51:15+00:00                             0
# 2002-07-03 17:59:22+00:00                             0
# ...                                                 ...
# 2021-10-14 00:19:31+00:00                             0
# 2021-10-14 00:19:44+00:00                             0
# 2021-10-14 00:22:15+00:00                             0
# 2021-10-17 00:46:31+00:00                             0
# 2021-10-17 04:55:14+00:00                             0
#
# [31633 rows x 27 columns]

# %%
rev_df_reversed[['comment','is_huggle_regex']]
# Out:
#                                                                                                                                          comment  \
# timestamp_dt
# 2001-10-25 07:48:17+00:00                                                                                                                      *
# 2001-11-14 17:35:37+00:00                                                                                                         link pop music
# 2001-11-14 17:38:44+00:00                                                                                        fix link to match GO's redirect
# 2002-02-25 15:51:15+00:00                                                                                                   Automated conversion
# 2002-07-03 17:59:22+00:00                                                                                                                      *
# ...                                                                                                                                          ...
# 2021-10-14 00:19:31+00:00                                                                                                           Cleaner text
# 2021-10-14 00:19:44+00:00                                                                                                                    fix
# 2021-10-14 00:22:15+00:00  /* top */ trying again to link [[List of Michael Jackson records and achievements]], seems very valuable for the lead
# 2021-10-17 00:46:31+00:00                                                                                       /* Death */ what the source says
# 2021-10-17 04:55:14+00:00                            source clearly says  Murray administered propofol and mixed it with lorazepam and midazolam
#
#                            is_huggle_regex
# timestamp_dt
# 2001-10-25 07:48:17+00:00                0
# 2001-11-14 17:35:37+00:00                0
# 2001-11-14 17:38:44+00:00                0
# 2002-02-25 15:51:15+00:00                0
# 2002-07-03 17:59:22+00:00                0
# ...                                    ...
# 2021-10-14 00:19:31+00:00                0
# 2021-10-14 00:19:44+00:00                0
# 2021-10-14 00:22:15+00:00                0
# 2021-10-17 00:46:31+00:00                0
# 2021-10-17 04:55:14+00:00                0
#
# [31633 rows x 2 columns]

# %%
pd.DataFrame(rev_df_reversed[['is_huggle_regex','is_huggle_tags']].corr())
# Out:
#                  is_huggle_regex  is_huggle_tags
# is_huggle_regex         1.000000        0.119392
# is_huggle_tags          0.119392        1.000000

# %%
pd.DataFrame(rev_df_reversed[['is_en_wikipedia_twinkle_regex','is_en_wikipedia_twinkle_tags']].corr())
# Out:
#                                is_en_wikipedia_twinkle_regex  \
# is_en_wikipedia_twinkle_regex                            1.0
# is_en_wikipedia_twinkle_tags                             NaN
#
#                                is_en_wikipedia_twinkle_tags
# is_en_wikipedia_twinkle_regex                           NaN
# is_en_wikipedia_twinkle_tags                            NaN

# %%
rev_df_reversed['is_huggle_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_huggle_tags'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_undo_tags'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_generic_rollback_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_undo_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_wikipedia_huggle_revert'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_wikipedia_botrevert_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_wikipedia_twinkle_regex'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>

# %%
rev_df_reversed['is_en_wikipedia_twinkle_tags'].rolling("365D", min_periods=1).mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='timestamp_dt'>
